# %% [markdown]
# ## 1. Datenbereinigung Unternehmen 1–50

# %%
import os
os.getcwd()
# Out:
# '/Users/liviaglauser/Bachelorarbeit'

# %%
import pandas as pd
import re
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Ergebnisse_1_50.xlsx")

# %%
id_col = "Unternehmensname Latin alphabet"

# %%
# Spalten mit USD droppen

# %%
usd_cols = df.columns[df.columns.str.contains("USD", case=False, na=False)]
df = df.drop(columns=usd_cols)

# %%
# Spalten mit tsd droppen

# %%
tsd_cols = df.columns[df.columns.str.contains("tsd", case=False, na=False)]
df = df.drop(columns=tsd_cols)

# %%
# Duplikate droppen

# %%
duplikate = df.columns[df.columns.str.contains(r"\.\d+$")]
df = df.drop(columns=duplikate)

# %%
# Spalten mit Letztes verf. Jahr droppen

# %%
df = df.loc[:, ~df.columns.str.contains("Letztes verf. Jahr", case=False)]

# %%
# n.v. mit NA ersetzen

# %%
df = df.replace("n.v.", pd.NA)

# %%
bilanzsumme_cols = [c for c in df.columns if "Bilanzsumme Aktiva" in c]
umlaufvermögen_cols = [c for c in df.columns if "Umlaufvermögen" in c]
zahlungsmittel_cols = [c for c in df.columns if "Zahlungsmittel & Zahlungsmitteläquivalente" in c]
kurz_verb_cols = [c for c in df.columns if "Kurzfristige Verbindlichkeiten" in c]
lang_verb_cols = [c for c in df.columns if "Langfristige Verbindlichkeiten" in c]
EK_cols = [c for c in df.columns if "Eigenkapital\nmil CHF" in c]
umsatz_cols = [c for c in df.columns if "Umsatz" in c]
EBIT_cols = [c for c in df.columns if "Betriebsgewinn/-verlust" in c]
finanzaufwendungen_cols = [c for c in df.columns if "Finanzaufwendungen" in c]
gewinn_verlust_cols = [c for c in df.columns if "Gewinn/Verlust vor Steuern" in c]
ROE_cols = [c for c in df.columns if "ROE basierend auf Gewinn/Verlust vor Steuern" in c]
ROA_cols = [c for c in df.columns if "ROA basierend auf Gewinn/Verlust vor Steuern" in c]
FK_zu_EK_cols = [c for c in df.columns if "Fremd- zu Eigenkapital" in c]
EK_quote_cols = [c for c in df.columns if "Eigenkapitalquote" in c]

# %%
# Wichtige Spalten erstellen

# %%
# Bilanzsumme Aktiva

# %%
bilanzsumme_long = df[[id_col] + bilanzsumme_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="Bilanzsumme"
)

# Jahr aus Spaltennamen ziehen
bilanzsumme_long["Jahr"] = (
    bilanzsumme_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)
# Aufräumen
bilanzsumme_long = bilanzsumme_long.drop(columns="Spalte")

# %%
# Eigenkapital

# %%
EK_long = df[[id_col] + EK_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="Eigenkapital"
)

# Jahr aus Spaltennamen ziehen
EK_long["Jahr"] = (
    EK_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)
# Aufräumen
EK_long = EK_long.drop(columns="Spalte")

# %%
# ROA

# %%
ROA_long = df[[id_col] + ROA_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="ROA"
)

# Jahr aus Spaltennamen ziehen
ROA_long["Jahr"] = (
    ROA_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)
# Aufräumen
ROA_long = ROA_long.drop(columns="Spalte")

# %%
# Kurzfristige Verbindlichkeiten

# %%
kurz_verb_long = df[[id_col] + kurz_verb_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="Kurzfristige_Verbindlichkeiten"
)

kurz_verb_long["Jahr"] = (
    kurz_verb_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)

kurz_verb_long = kurz_verb_long.drop(columns="Spalte")

# %%
# Langfristige Verbindlichkeiten

# %%
lang_verb_long = df[[id_col] + lang_verb_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="Langfristige_Verbindlichkeiten"
)

lang_verb_long["Jahr"] = (
    lang_verb_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)

lang_verb_long = lang_verb_long.drop(columns="Spalte")

# %%
# Eigenkapital Quote

# %%
EK_quote_long = df[[id_col] + EK_quote_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="EK_Quote"
)

EK_quote_long["Jahr"] = (
    EK_quote_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)

EK_quote_long = EK_quote_long.drop(columns="Spalte")

# %%
# Umsatz

# %%
umsatz_long = df[[id_col] + umsatz_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="Umsatz"
)

umsatz_long["Jahr"] = (
    umsatz_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)

umsatz_long = umsatz_long.drop(columns="Spalte")

# %%
# Zahlungsmittel

# %%
zahlungsmittel_long = df[[id_col] + zahlungsmittel_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="Zahlungsmittel"
)

# Jahr aus Spaltennamen ziehen
zahlungsmittel_long["Jahr"] = (
    zahlungsmittel_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)
# Aufräumen
zahlungsmittel_long = zahlungsmittel_long.drop(columns="Spalte")

# %%
panel = (
    bilanzsumme_long
    .merge(zahlungsmittel_long, on=[id_col, "Jahr"], how="outer")
    .merge(ROA_long,            on=[id_col, "Jahr"], how="outer")
    .merge(EK_long,             on=[id_col, "Jahr"], how="outer")
    .merge(kurz_verb_long,      on=[id_col, "Jahr"], how="outer")
    .merge(lang_verb_long,      on=[id_col, "Jahr"], how="outer")
    .merge(EK_quote_long,       on=[id_col, "Jahr"], how="outer")
    .merge(umsatz_long,         on=[id_col, "Jahr"], how="outer")
)

Unternehmensdaten_1_50 = panel.sort_values([id_col, "Jahr"]).reset_index(drop=True)

# %%
#Unternehmensdaten.to_csv("Unternehmensdaten.csv", index=False)

# %% [markdown]
# ## 2. Datenbereinigung Unternehmen 50–70

# %%
df = pd.read_excel("Ergebnisse_50_70.xlsx")

# %%
# Spalten mit USD droppen

# %%
usd_cols = df.columns[df.columns.str.contains("USD", case=False, na=False)]
df = df.drop(columns=usd_cols)

# %%
# Spalten mit tsd droppen

# %%
tsd_cols = df.columns[df.columns.str.contains("tsd", case=False, na=False)]
df = df.drop(columns=tsd_cols)

# %%
# Duplikate droppen

# %%
duplikate = df.columns[df.columns.str.contains(r"\.\d+$")]
df = df.drop(columns=duplikate)

# %%
# Spalten mir Letztes verf. Jahr droppen

# %%
df = df.loc[:, ~df.columns.str.contains("Letztes verf. Jahr", case=False)]

# %%
# n.v. mit NA ersetzen

# %%
df = df.replace("n.v.", pd.NA)

# %%
bilanzsumme_cols = [c for c in df.columns if "Bilanzsumme Aktiva" in c]
umlaufvermögen_cols = [c for c in df.columns if "Umlaufvermögen" in c]
zahlungsmittel_cols = [c for c in df.columns if "Zahlungsmittel & Zahlungsmitteläquivalente" in c]
kurz_verb_cols = [c for c in df.columns if "Kurzfristige Verbindlichkeiten" in c]
lang_verb_cols = [c for c in df.columns if "Langfristige Verbindlichkeiten" in c]
EK_cols = [c for c in df.columns if "Eigenkapital\nmil CHF" in c]
umsatz_cols = [c for c in df.columns if "Umsatz" in c]
EBIT_cols = [c for c in df.columns if "Betriebsgewinn/-verlust" in c]
finanzaufwendungen_cols = [c for c in df.columns if "Finanzaufwendungen" in c]
gewinn_verlust_cols = [c for c in df.columns if "Gewinn/Verlust vor Steuern" in c]
ROE_cols = [c for c in df.columns if "ROE basierend auf Gewinn/Verlust vor Steuern" in c]
ROA_cols = [c for c in df.columns if "ROA basierend auf Gewinn/Verlust vor Steuern" in c]
FK_zu_EK_cols = [c for c in df.columns if "Fremd- zu Eigenkapital" in c]
EK_quote_cols = [c for c in df.columns if "Eigenkapitalquote" in c]

# %%
# Wichtige Spalten erstellen

# %%
# Bilanzsumme Aktiva

# %%
bilanzsumme_long = df[[id_col] + bilanzsumme_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="Bilanzsumme"
)

# Jahr aus Spaltennamen ziehen
bilanzsumme_long["Jahr"] = (
    bilanzsumme_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)
# Aufräumen
bilanzsumme_long = bilanzsumme_long.drop(columns="Spalte")

# %%
# Eigenkapital

# %%
EK_long = df[[id_col] + EK_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="Eigenkapital"
)

# Jahr aus Spaltennamen ziehen
EK_long["Jahr"] = (
    EK_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)
# Aufräumen
EK_long = EK_long.drop(columns="Spalte")

# %%
# ROA

# %%
ROA_long = df[[id_col] + ROA_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="ROA"
)

# Jahr aus Spaltennamen ziehen
ROA_long["Jahr"] = (
    ROA_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)
# Aufräumen
ROA_long = ROA_long.drop(columns="Spalte")

# %%
# Kurzfristige Verbindlichkeiten

# %%
kurz_verb_long = df[[id_col] + kurz_verb_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="Kurzfristige_Verbindlichkeiten"
)

kurz_verb_long["Jahr"] = (
    kurz_verb_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)

kurz_verb_long = kurz_verb_long.drop(columns="Spalte")

# %%
# Langfristige Verbindlichkeiten

# %%
lang_verb_long = df[[id_col] + lang_verb_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="Langfristige_Verbindlichkeiten"
)

lang_verb_long["Jahr"] = (
    lang_verb_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)

lang_verb_long = lang_verb_long.drop(columns="Spalte")

# %%
# Eigenkapital Quote

# %%
EK_quote_long = df[[id_col] + EK_quote_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="EK_Quote"
)

EK_quote_long["Jahr"] = (
    EK_quote_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)

EK_quote_long = EK_quote_long.drop(columns="Spalte")

# %%
# Umsatz

# %%
umsatz_long = df[[id_col] + umsatz_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="Umsatz"
)

umsatz_long["Jahr"] = (
    umsatz_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)

umsatz_long = umsatz_long.drop(columns="Spalte")

# %%
# Zahlungsmittel

# %%
zahlungsmittel_long = df[[id_col] + zahlungsmittel_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="Zahlungsmittel"
)

# Jahr aus Spaltennamen ziehen
zahlungsmittel_long["Jahr"] = (
    zahlungsmittel_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)
# Aufräumen
zahlungsmittel_long = zahlungsmittel_long.drop(columns="Spalte")

# %%
panel = (
    bilanzsumme_long
    .merge(zahlungsmittel_long, on=[id_col, "Jahr"], how="outer")
    .merge(ROA_long,            on=[id_col, "Jahr"], how="outer")
    .merge(EK_long,             on=[id_col, "Jahr"], how="outer")
    .merge(kurz_verb_long,      on=[id_col, "Jahr"], how="outer")
    .merge(lang_verb_long,      on=[id_col, "Jahr"], how="outer")
    .merge(EK_quote_long,       on=[id_col, "Jahr"], how="outer")
    .merge(umsatz_long,         on=[id_col, "Jahr"], how="outer")
)

Unternehmensdaten_50_70 = panel.sort_values([id_col, "Jahr"]).reset_index(drop=True)

# %%
#Unternehmensdaten_50_70.to_csv("Unternehmensdaten_50_70.csv", index=False)

# %% [markdown]
# ## 3. Datenbereinigung Unternehmen 70–90

# %%
df = pd.read_excel("Ergebnisse_70_90.xlsx")

# %%
# Spalten mit USD droppen

# %%
usd_cols = df.columns[df.columns.str.contains("USD", case=False, na=False)]
df = df.drop(columns=usd_cols)

# %%
# Spalten mit tsd droppen

# %%
tsd_cols = df.columns[df.columns.str.contains("tsd", case=False, na=False)]
df = df.drop(columns=tsd_cols)

# %%
# Duplikate droppen

# %%
duplikate = df.columns[df.columns.str.contains(r"\.\d+$")]
df = df.drop(columns=duplikate)

# %%
# Spalten mit Letztes verf. Jahr droppen

# %%
df = df.loc[:, ~df.columns.str.contains("Letztes verf. Jahr", case=False)]

# %%
# n.v. mit NA ersetzen

# %%
df = df.replace("n.v.", pd.NA)

# %%
bilanzsumme_cols = [c for c in df.columns if "Bilanzsumme Aktiva" in c]
umlaufvermögen_cols = [c for c in df.columns if "Umlaufvermögen" in c]
zahlungsmittel_cols = [c for c in df.columns if "Zahlungsmittel & Zahlungsmitteläquivalente" in c]
kurz_verb_cols = [c for c in df.columns if "Kurzfristige Verbindlichkeiten" in c]
lang_verb_cols = [c for c in df.columns if "Langfristige Verbindlichkeiten" in c]
EK_cols = [c for c in df.columns if "Eigenkapital\nmil CHF" in c]
umsatz_cols = [c for c in df.columns if "Umsatz" in c]
EBIT_cols = [c for c in df.columns if "Betriebsgewinn/-verlust" in c]
finanzaufwendungen_cols = [c for c in df.columns if "Finanzaufwendungen" in c]
gewinn_verlust_cols = [c for c in df.columns if "Gewinn/Verlust vor Steuern" in c]
ROE_cols = [c for c in df.columns if "ROE basierend auf Gewinn/Verlust vor Steuern" in c]
ROA_cols = [c for c in df.columns if "ROA basierend auf Gewinn/Verlust vor Steuern" in c]
FK_zu_EK_cols = [c for c in df.columns if "Fremd- zu Eigenkapital" in c]
EK_quote_cols = [c for c in df.columns if "Eigenkapitalquote" in c]

# %%
# Wichtige Spalten erstellen

# %%
# Bilanzsumme Aktiva

# %%
bilanzsumme_long = df[[id_col] + bilanzsumme_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="Bilanzsumme"
)

# Jahr aus Spaltennamen ziehen
bilanzsumme_long["Jahr"] = (
    bilanzsumme_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)
# Aufräumen
bilanzsumme_long = bilanzsumme_long.drop(columns="Spalte")

# %%
# Eigenkapital

# %%
EK_long = df[[id_col] + EK_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="Eigenkapital"
)

# Jahr aus Spaltennamen ziehen
EK_long["Jahr"] = (
    EK_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)
# Aufräumen
EK_long = EK_long.drop(columns="Spalte")

# %%
# ROA

# %%
ROA_long = df[[id_col] + ROA_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="ROA"
)

# Jahr aus Spaltennamen ziehen
ROA_long["Jahr"] = (
    ROA_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)
# Aufräumen
ROA_long = ROA_long.drop(columns="Spalte")

# %%
# Kurzfristige Verbindlichkeiten

# %%
kurz_verb_long = df[[id_col] + kurz_verb_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="Kurzfristige_Verbindlichkeiten"
)

kurz_verb_long["Jahr"] = (
    kurz_verb_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)

kurz_verb_long = kurz_verb_long.drop(columns="Spalte")

# %%
# Langfristige Verbindlichkeiten

# %%
lang_verb_long = df[[id_col] + lang_verb_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="Langfristige_Verbindlichkeiten"
)

lang_verb_long["Jahr"] = (
    lang_verb_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)

lang_verb_long = lang_verb_long.drop(columns="Spalte")

# %%
# Eigenkapital Quote

# %%
EK_quote_long = df[[id_col] + EK_quote_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="EK_Quote"
)

EK_quote_long["Jahr"] = (
    EK_quote_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)

EK_quote_long = EK_quote_long.drop(columns="Spalte")

# %%
# Umsatz

# %%
umsatz_long = df[[id_col] + umsatz_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="Umsatz"
)

umsatz_long["Jahr"] = (
    umsatz_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)

umsatz_long = umsatz_long.drop(columns="Spalte")

# %%
# Zahlungsmittel

# %%
zahlungsmittel_long = df[[id_col] + zahlungsmittel_cols].melt(
    id_vars=id_col,
    var_name="Spalte",
    value_name="Zahlungsmittel"
)

# Jahr aus Spaltennamen ziehen
zahlungsmittel_long["Jahr"] = (
    zahlungsmittel_long["Spalte"]
    .astype(str)
    .str.extract(r"(\d{4})")
    .astype(int)
)
# Aufräumen
zahlungsmittel_long = zahlungsmittel_long.drop(columns="Spalte")

# %%
panel = (
    bilanzsumme_long
    .merge(zahlungsmittel_long, on=[id_col, "Jahr"], how="outer")
    .merge(ROA_long,            on=[id_col, "Jahr"], how="outer")
    .merge(EK_long,             on=[id_col, "Jahr"], how="outer")
    .merge(kurz_verb_long,      on=[id_col, "Jahr"], how="outer")
    .merge(lang_verb_long,      on=[id_col, "Jahr"], how="outer")
    .merge(EK_quote_long,       on=[id_col, "Jahr"], how="outer")
    .merge(umsatz_long,         on=[id_col, "Jahr"], how="outer")
)

Unternehmensdaten_70_90 = panel.sort_values([id_col, "Jahr"]).reset_index(drop=True)

# %%
#Unternehmensdaten_70_90.to_csv("Unternehmensdaten_70_90.csv", index=False)

# %% [markdown]
# ## 4. Zusammenführen der Unternehmensdaten

# %%
# Bereinigte Daten umbenennen

# %%
df1 = Unternehmensdaten_1_50
df2 = Unternehmensdaten_50_70
df3 = Unternehmensdaten_70_90

# %%
# dataframes zusammenfügen

# %%
df_all = pd.concat([df1, df2, df3], axis=0, ignore_index=True)

# %%
df_all = df_all.sort_values([id_col, "Jahr"]).reset_index(drop=True)

# %%
#df_all.to_csv("Unternehmensdaten_final_.csv", index=False)

# %% [markdown]
# ## 5. Filterung 2016–2024

# %%
df = df_all

# %%
# Datenzeitrum von 2016 bis 2025 setzen

# %%
years = list(range(2016, 2025))

# Nur relevante Jahre
df_sub = df[df["Jahr"].isin(years)]

# Unternehmen, die in allen Jahren vorhanden sind
valid_companies = (
    df_sub
    .groupby(id_col)
    .filter(lambda x: 
            x["Jahr"].nunique() == len(years) and
            x.notna().all().all()
           )
)

# Einzelne Unternehmen
valid_companies[id_col].nunique()
# Out:
# 318

# %%
df_2016_2025 = df[df["Jahr"].isin(range(2016, 2025))]

# %%
# Unternehmen behalten, die KEIN einziges NaN haben
df_no_nan_companies = (
    df_2016_2025
    .groupby(id_col)
    .filter(lambda x: not x.isna().any().any())
)

# %%
Unternehmen = df_no_nan_companies

# %%
#df_no_nan_companies.to_csv("Unternehmensdaten_16_24.csv", index=False)

# %% [markdown]
# ## 6. Zinsdaten und berechnete Variablen hinzufügen

# %%
# Zinsdaten als Dataframe schreiben
Zins = pd.DataFrame({
    "Jahr": [
        2016,2017,2018,2019,
        2020,2021,2022,2023,2024
    ],
    "Zinsschock": [
        -0.44,
        -0.775,-0.04,1.6,3.62,0.25,22.6,-20.407,-33.391
    ],
    "ABS": [
        2.84,
        0.775,0.72,2,4.9,0.25,64.6,44.581,50.823
    ]
})

# %%
# Unternehmens- und Zinsdaten zusammenfügen
df_merged = Unternehmen.merge(
    Zins,
    on="Jahr",
    how="left"
)

# %%
df_merged["Bilanzsumme"] = pd.to_numeric(
    df_merged["Bilanzsumme"],
    errors="coerce"
)

# %%
# Zinswernde-Dummy erstellen
df_merged["Zinswende_Dummy"] = (df_merged["Jahr"] >= 2022).astype(int)

# %%
# Variablen Berechnen

# %%
df_merged["Cash_Ratio"] = (
    df_merged["Zahlungsmittel"] / df_merged["Bilanzsumme"]
)

# %%
df_merged["Groesse_Log_Bilanzsumme"] = np.log(df_merged["Bilanzsumme"])

# %%
pre_years = range(2016, 2022)  # 2016–2021

# %%
df_merged["Leverage"] = (
    (df_merged["Kurzfristige_Verbindlichkeiten"]
     + df_merged["Langfristige_Verbindlichkeiten"])
    / df_merged["Bilanzsumme"]
)

# %%
leverage_exante = (
    df_merged[df_merged["Jahr"].isin(pre_years)]
    .groupby(id_col)["Leverage"]
    .mean()
)

# %%
df_merged["Leverage_exante"] = df_merged[company_col].map(leverage_exante)

# %%
liquidity_exante = (
    df_merged[df_merged["Jahr"].isin(pre_years)]
    .groupby(id_col)["Cash_Ratio"]
    .mean()
)

# %%
df_merged["Liquidity_exante"] = df_merged[id_col].map(liquidity_exante)

# %%
df_merged["STDebtShare"] = (
    df_merged["Kurzfristige_Verbindlichkeiten"] /
    (df_merged["Kurzfristige_Verbindlichkeiten"]
     + df_merged["Langfristige_Verbindlichkeiten"])
)

# %%
stdebt_exante = (
    df_merged[df_merged["Jahr"].isin(pre_years)]
    .groupby(company_col)["STDebtShare"]
    .mean()
)

# %%
df_merged["STDebtShare_exante"] = df_merged[company_col].map(stdebt_exante)

# %% [markdown]
# ## 7. Letzte Missing-Value Bereinigung

# %%
df = df_merged

# %%
df = df.replace(["n.s.", "n.s", "NA", "na", ""], np.nan)
# Out:
# /var/folders/nd/8mtd0whj6w70jg2l1j9rsy0r0000gn/T/ipykernel_32701/1155019838.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(["n.s.", "n.s", "NA", "na", ""], np.nan)

# %%
df[df.isna().any(axis=1)]
# Out:
#            Unternehmensname Latin alphabet  Bilanzsumme  Jahr  Zahlungsmittel  \
# 0                    ADDEX THERAPEUTICS SA     1.683000  2016        1.416000
# 1                    ADDEX THERAPEUTICS SA     3.063000  2017        2.591000
# 6                    ADDEX THERAPEUTICS SA     8.282000  2022        6.961000
# 7                    ADDEX THERAPEUTICS SA     4.642000  2023        3.866000
# 1331                   HOCHDORF HOLDING AG    16.034000  2024       15.783000
# 2077        RELIEF THERAPEUTICS HOLDING AG    76.390000  2023       14.556000
# 2175  SANTHERA PHARMACEUTICALS HOLDING LTD    63.726000  2022        1.353000
# 2763      WISEKEY INTERNATIONAL HOLDING AG    34.170112  2016        5.304536
#
#       ROA  Eigenkapital  Kurzfristige_Verbindlichkeiten  \
# 0     NaN      0.219000                        1.250000
# 1     NaN      1.343000                        1.477000
# 6     NaN      4.913000                        3.282000
# 7     NaN      1.145000                        2.893000
# 1331  NaN     13.791000                        2.242000
# 2077  NaN     52.228000                        6.909000
# 2175  NaN    -43.686000                       49.414000
# 2763  NaN      1.942592                       25.990296
#
#       Langfristige_Verbindlichkeiten  EK_Quote      Umsatz  Zinsschock  \
# 0                           0.214000    13.012    0.000000      -0.440
# 1                           0.243000    43.846    0.000000      -0.775
# 6                           0.087000    59.321    1.422000      22.600
# 7                           0.604000    24.666    1.613000     -20.407
# 1331                        0.001000    86.011  241.189000     -33.391
# 2077                       17.253000    68.370    6.033000     -20.407
# 2175                       57.998000   -68.553    7.473000      22.600
# 2763                        6.237224     5.685   11.137392      -0.440
#
#          ABS  Zinswende_Dummy  Cash_Ratio  Groesse_Log_Bilanzsumme  Leverage  \
# 0      2.840                0    0.841355                 0.520578  0.869875
# 1      0.775                0    0.845903                 1.119395  0.561541
# 6     64.600                1    0.840497                 2.114084  0.406786
# 7     44.581                1    0.832831                 1.535145  0.753339
# 1331  50.823                1    0.984346                 2.774711  0.139890
# 2077  44.581                1    0.190549                 4.335852  0.316298
# 2175  64.600                1    0.021232                 4.154593  1.685529
# 2763   2.840                0    0.155239                 3.531351  0.943149
#
#       Leverage_exante  Liquidity_exante  STDebtShare  STDebtShare_exante
# 0            0.375678          0.911484     0.853825            0.773563
# 1            0.375678          0.911484     0.858721            0.773563
# 6            0.375678          0.911484     0.974176            0.773563
# 7            0.375678          0.911484     0.827281            0.773563
# 1331         0.524033          0.081644     0.999554            0.401213
# 2077         0.286256          0.127340     0.285945            0.319424
# 2175         0.751223          0.331817     0.460042            0.326703
# 2763         0.756909          0.287882     0.806463            0.595501

# %%
unternehmen_loeschen = [
    "ADDEX THERAPEUTICS SA",
    "HOCHDORF HOLDING AG",
    "RELIEF THERAPEUTICS HOLDING AG",
    "SANTHERA PHARMACEUTICALS HOLDING LTD",
    "WISEKEY INTERNATIONAL HOLDING AG"
]

df = df[~df['Unternehmensname Latin alphabet'].isin(unternehmen_loeschen)]

# %%
df
# Out:
#      Unternehmensname Latin alphabet   Bilanzsumme  Jahr  Zahlungsmittel  \
# 9                    ADECCO GROUP AG  10815.676995  2016     1208.048683
# 10                   ADECCO GROUP AG  11568.104335  2017     1125.229158
# 11                   ADECCO GROUP AG  10956.870613  2018      735.118300
# 12                   ADECCO GROUP AG  11497.820557  2019     1469.449964
# 13                   ADECCO GROUP AG  10588.284394  2020     1605.760041
# ...                              ...           ...   ...             ...
# 2893               ZWAHLEN & MAYR SA     52.759000  2020        5.152000
# 2894               ZWAHLEN & MAYR SA     52.071000  2021        2.726000
# 2895               ZWAHLEN & MAYR SA     58.734000  2022        1.714000
# 2896               ZWAHLEN & MAYR SA     59.670000  2023        0.905000
# 2897               ZWAHLEN & MAYR SA     54.047000  2024        1.294000
#
#          ROA  Eigenkapital  Kurzfristige_Verbindlichkeiten  \
# 9     10.249   3986.132268                     4686.543473
# 10     9.494   4189.782581                     5216.758881
# 11     7.481   4046.533096                     4905.674423
# 12    10.179   4294.143937                     4866.261392
# 13     0.694   3479.687416                     4824.849363
# ...      ...           ...                             ...
# 2893  -3.717     38.154000                        9.161000
# 2894   2.278     39.170000                        8.860000
# 2895   2.556     40.364000                       14.063000
# 2896   1.373     41.071000                       14.092000
# 2897  -9.712     36.425000                       14.727000
#
#       Langfristige_Verbindlichkeiten  EK_Quote        Umsatz  Zinsschock  \
# 9                        2143.001254    36.855  24319.476503      -0.440
# 10                       2161.562873    36.218  27674.554960      -0.775
# 11                       2004.663094    36.931  26909.614214      -0.040
# 12                       2337.415228    37.347  25480.980247       1.600
# 13                       2283.747614    32.864  21151.698430       3.620
# ...                              ...       ...           ...         ...
# 2893                        5.444000    72.318     41.895000       3.620
# 2894                        4.041000    75.224     55.776000       0.250
# 2895                        4.307000    68.723     56.249000      22.600
# 2896                        4.507000    68.830     53.776000     -20.407
# 2897                        2.895000    67.395     40.688000     -33.391
#
#          ABS  Zinswende_Dummy  Cash_Ratio  Groesse_Log_Bilanzsumme  Leverage  \
# 9      2.840                0    0.111694                 9.288752  0.631449
# 10     0.775                0    0.097270                 9.356007  0.637816
# 11     0.720                0    0.067092                 9.301722  0.630685
# 12     2.000                0    0.127802                 9.349913  0.626525
# 13     4.900                0    0.151654                 9.267503  0.671364
# ...      ...              ...         ...                      ...       ...
# 2893   4.900                0    0.097652                 3.965734  0.276825
# 2894   0.250                0    0.052352                 3.952608  0.247758
# 2895  64.600                1    0.029182                 4.073019  0.312766
# 2896  44.581                1    0.015167                 4.088829  0.311698
# 2897  50.823                1    0.023942                 3.989854  0.326050
#
#       Leverage_exante  Liquidity_exante  STDebtShare  STDebtShare_exante
# 9            0.646262          0.135443     0.686216            0.673901
# 10           0.646262          0.135443     0.707039            0.673901
# 11           0.646262          0.135443     0.709904            0.673901
# 12           0.646262          0.135443     0.675525            0.673901
# 13           0.646262          0.135443     0.678734            0.673901
# ...               ...               ...          ...                 ...
# 2893         0.296519          0.069610     0.627251            0.671236
# 2894         0.296519          0.069610     0.686768            0.671236
# 2895         0.296519          0.069610     0.765542            0.671236
# 2896         0.296519          0.069610     0.757675            0.671236
# 2897         0.296519          0.069610     0.835717            0.671236
#
# [2853 rows x 20 columns]

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
#df.to_csv("final_df.csv", index=False)
